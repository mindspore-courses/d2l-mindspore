# %% [markdown]
# # 线性回归的从零开始实现
#
# 我们将从零开始实现整个方法，包括数据流水线、模型、损失函数和小批量随机梯度下降优化器

# %%
# %matplotlib inline
import random
import mindspore
import mindspore.numpy as mnp
import mindspore.ops as ops
from mindspore import Tensor

# %%
import sys
sys.path.append('..')
from d2l import mindspore as d2l

# %% [markdown]
# 根据带有噪声的线性模型构造一个人造数据集。
# 我们使用线性模型参数$\mathbf{w} = [2, -3.4]^\top$、$b = 4.2$和噪声项$\epsilon$生成数据集及其标签：
#
# $$\mathbf{y}= \mathbf{X} \mathbf{w} + b + \mathbf\epsilon$$

# %%
def synthetic_data(w, b, num_examples):  
    """生成 y = Xw + b + 噪声。"""
    X = ops.normal((num_examples, len(w)), Tensor(0, mindspore.int32), Tensor(1, mindspore.int32))
    y = ops.matmul(X, w) + b
    y += ops.normal(y.shape, Tensor(0, mindspore.int32), Tensor(0.01, mindspore.float32))
    return X, y.reshape((-1, 1))

true_w = Tensor([2, -3.4], mindspore.float32)
true_b = 4.2
features, labels = synthetic_data(true_w, true_b, 1000)
# Out:
# [WARNING] KERNEL(2982708,7f1327423740,python):2021-10-29-15:44:39.078.494 [mindspore/ccsrc/backend/kernel_compiler/gpu/gpu_kernel_factory.cc:96] ReducePrecision] Kernel [StandardNormal] does not support int64, cast input 0 to int32.
# [WARNING] PRE_ACT(2982708,7f1327423740,python):2021-10-29-15:44:39.078.570 [mindspore/ccsrc/backend/optimizer/gpu/reduce_precision_fusion.cc:83] Run] Reduce precision for [StandardNormal] input 0
# [WARNING] KERNEL(2982708,7f1327423740,python):2021-10-29-15:44:39.098.631 [mindspore/ccsrc/backend/kernel_compiler/gpu/gpu_kernel_factory.cc:96] ReducePrecision] Kernel [StandardNormal] does not support int64, cast input 0 to int32.
# [WARNING] PRE_ACT(2982708,7f1327423740,python):2021-10-29-15:44:39.098.727 [mindspore/ccsrc/backend/optimizer/gpu/reduce_precision_fusion.cc:83] Run] Reduce precision for [StandardNormal] input 0

# %% [markdown]
# `features`中的每一行都包含一个二维数据样本，`labels`中的每一行都包含一维标签值（一个标量）

# %%
print('features:', features[0],'\nlabel:', labels[0])
# Out:
# features: [ 1.1876262 -1.1357044]
# label: [10.435598]

# %%
d2l.set_figsize()
d2l.plt.scatter(features[:, (1)].asnumpy(), labels.asnumpy(), 1);

# %% [markdown]
# 定义一个`data_iter`函数，
# 该函数接收批量大小、特征矩阵和标签向量作为输入，生成大小为`batch_size`的小批量

# %%
def data_iter(batch_size, features, labels):
    num_examples = len(features)
    indices = list(range(num_examples))
    random.shuffle(indices)
    for i in range(0, num_examples, batch_size):
        batch_indices = Tensor(
            indices[i: min(i + batch_size, num_examples)])
        yield features[batch_indices], labels[batch_indices]

batch_size = 10

for X, y in data_iter(batch_size, features, labels):
    print(X, '\n', y)
    break
# Out:
# [[ 3.2068045   0.9953926 ]
#  [-0.6924101   2.1172616 ]
#  [-0.32126245 -1.2445008 ]
#  [-2.6174076   0.01847371]
#  [ 0.62240916 -0.98249424]
#  [ 2.0716913   0.14817062]
#  [-0.27354497 -1.3411192 ]
#  [ 1.1063837   0.06256448]
#  [-1.1564741   0.43213332]
#  [-1.7418164  -0.5340148 ]]
#  [[ 7.230056  ]
#  [-4.3848333 ]
#  [ 7.78687   ]
#  [-1.0953857 ]
#  [ 8.786238  ]
#  [ 7.8556247 ]
#  [ 8.234009  ]
#  [ 6.185843  ]
#  [ 0.42280954]
#  [ 2.5343368 ]]

# %% [markdown]
# 在我们开始用小批量随机梯度下降优化我们的模型参数之前，需要说明一下MindSpore的设计理念。MindSpore的静态图思路是将整个模型视作一个完整的计算图，即模型、Loss、优化器均需要作为计算图的一部分。这与Pytorch的使用习惯有些不符。接下来将通过线性回归的例子来体现：

# %% [markdown]
# 定义模型，定义模型的参数，模型的输入输出。这里需要用到`nn.Cell`，因为只有这样才能够使编译器识别编译为计算图。

# %%
import mindspore.nn as nn
from mindspore import Parameter
from mindspore.common.initializer import initializer, Zero, Normal

class Linreg(nn.Cell):
    def __init__(self):
        super().__init__()
        self.w = Parameter(initializer(Normal(0.01, 0), (2, 1), mindspore.float32))
        self.b = Parameter(initializer(Zero(), 1, mindspore.float32))
        
    def construct(self, x):
        # construct内为正向的执行逻辑，也是计算图的正向连接表达
        return ops.matmul(x, self.w) + self.b

# %% [markdown]
# 定义损失函数。损失函数也需要定义为`nn.Cell`的子类

# %%
class SquaredLoss(nn.Cell):
    def construct(self, y_hat, y):  
        """均方损失。"""
        return (y_hat - y.reshape(y_hat.shape)) ** 2 / 2

# %% [markdown]
# 定义优化算法
# 尽管线性回归有解析解，但本书中的其他模型却没有。这里我们介绍小批量随机梯度下降

# %%
class SGD(nn.Cell):
    def __init__(self, lr, batch_size, params):
        super().__init__()
        self.lr = lr
        self.batch_size = batch_size
        self.params = params
        
    def construct(self, grads):
        for idx in range(len(self.params)):
            ops.assign(self.params[idx], self.params[idx] - self.lr * grads[idx] / self.batch_size)
            # 这里用到了一个assign算子，因为静态图里无法直接使用x = x + y来更新权重，采用assign算子实际上是为了
            # 能够给权重赋值，覆盖旧的权重数据
        return True

# %% [markdown]
# 按照上面的叙述，需要讲network和loss连接

# %%
class Net(nn.Cell):
    def __init__(self):
        super().__init__()
        self.linreg = Linreg()
        self.loss = SquaredLoss()
        
    def construct(self, x, y):
        y_hat = self.linreg(x)
        loss = self.loss(y_hat, y)
        return loss

# %% [markdown]
# 训练过程。其实包括三步，分别为：
#
# 1. 计算正向结果
# 2. 计算反向梯度
# 3. 更新权重
#
# 按照上面的叙述，需要将network、loss、optimizer连接，作为一个完整的计算图。因此也要继承`nn.Cell`

# %%
class Train(nn.Cell):
    def __init__(self, network, optimizer):
        super().__init__()
        self.network = network
        self.optimizer = optimizer
        self.grad = ops.GradOperation(get_by_list=True)
        
    def construct(self, x, y):
        loss = self.network(x, y)
        grads = self.grad(self.network, self.optimizer.params)(x, y)
        loss = ops.depend(loss, self.optimizer(grads))
        return loss

# %%
lr = 0.03
num_epochs = 3
net = Net()
optim = SGD(lr, batch_size, net.trainable_params())
train = Train(net, optim)

# %%
for epoch in range(num_epochs):
    for x, y in data_iter(batch_size, features, labels):
        l = train(x, y)
    train_l = net(features, labels)
    print(f'epoch {epoch + 1}, loss {float(train_l.mean().asnumpy()):f}')
# Out:
# epoch 1, loss 0.042639
# epoch 2, loss 0.000170
# epoch 3, loss 0.000053

# %% [markdown]
# 比较真实参数和通过训练学到的参数来评估训练的成功程度

# %%
print(f'w的估计误差: {true_w - net.trainable_params()[0].reshape(true_w.shape)}')
print(f'b的估计误差: {true_b - net.trainable_params()[1]}')
# Out:
# w的估计误差: [-0.00020528 -0.00016379]
# b的估计误差: [-0.00035286]
