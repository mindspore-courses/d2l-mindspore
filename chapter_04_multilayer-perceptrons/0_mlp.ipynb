# %% [markdown]
# # 多层感知机
#
# 简要介绍一些常见的激活函数

# %%
import sys
sys.path.append('..')

# %%
# %matplotlib inline
from d2l import mindspore as d2l
import mindspore

# %% [markdown]
# ReLU提供了一种非常简单的非线性变换

# %%
x = d2l.arange(-8.0, 8.0, 0.1)
y = d2l.relu(x)
d2l.plot(x.asnumpy(), y.asnumpy(), 'x', 'relu(x)', figsize=(5, 2.5))

# %%
grad_fn = mindspore.grad(d2l.relu, (0))
x_grad = grad_fn(x)
d2l.plot(x.asnumpy(), x_grad.asnumpy(), 'x', 'grad of relu', figsize=(5, 2.5))
# Out:
# [WARNING] OPTIMIZER(3693371,7fc3754eb740,python):2021-11-03-08:19:45.768.547 [mindspore/ccsrc/frontend/optimizer/ad/dfunctor.cc:803] GetPrimalUser] J operation has no relevant primal call in the same graph. Func graph: 1_after_grad.2, J user: 1_after_grad.2:relu{[0]: 3, [1]: args0}

# %% [markdown]
# 对于一个定义域在$\mathbb{R}$中的输入，*sigmoid函数*将输入变换为区间(0, 1)上的输出

# %%
y = d2l.sigmoid(x)
d2l.plot(x.asnumpy(), y.asnumpy(), 'x', 'sigmoid(x)', figsize=(5, 2.5))

# %%
grad_fn = mindspore.grad(d2l.sigmoid, (0))
x_grad = grad_fn(x)
d2l.plot(x.asnumpy(), x_grad.asnumpy(), 'x', 'grad of sigmoid', figsize=(5, 2.5))
# Out:
# [WARNING] OPTIMIZER(3693371,7fc3754eb740,python):2021-11-03-08:19:46.182.551 [mindspore/ccsrc/frontend/optimizer/ad/dfunctor.cc:803] GetPrimalUser] J operation has no relevant primal call in the same graph. Func graph: 14_after_grad.8, J user: 14_after_grad.8:sigmoid{[0]: 9, [1]: args0}

# %% [markdown]
# Tanh(双曲正切)函数也能将其输入压缩转换到区间(-1, 1)上

# %%
y = d2l.tanh(x)
d2l.plot(x.asnumpy(), y.asnumpy(), 'x', 'tanh(x)', figsize=(5, 2.5))

# %%
grad_fn = mindspore.grad(d2l.tanh, (0))
x_grad = grad_fn(x)
d2l.plot(x.asnumpy(), x_grad.asnumpy(), 'x', 'grad of tanh', figsize=(5, 2.5))
# Out:
# [WARNING] OPTIMIZER(3693371,7fc3754eb740,python):2021-11-03-08:19:46.536.717 [mindspore/ccsrc/frontend/optimizer/ad/dfunctor.cc:803] GetPrimalUser] J operation has no relevant primal call in the same graph. Func graph: 27_after_grad.14, J user: 27_after_grad.14:tanh{[0]: 15, [1]: args0}
